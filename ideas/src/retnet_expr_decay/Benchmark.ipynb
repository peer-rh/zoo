# %% [markdown]
# ## Findings
# - jax.scan compiles faster, altough performs worse for 1 block
# - For larger block sizes this seems to be no longer true and the two become similar in performance
# - => I will employ the scan function since it'll either match performance (or even scale better) and

# %%
from __init__ import Config, ExpressiveRetNet
import jax
import jax.numpy as jnp
import equinox as eqx
import optax
import timeit

# %%
key = jax.random.PRNGKey(0)
seq_len = 4096
config = Config(
    n_heads=4,
    d_model=512,
    n_layers=4,
    d_mlp=1024,
)
csz = 128
model = ExpressiveRetNet(config, key)
X = jax.random.randint(key, (seq_len,), 0, config.n_vocab)
Y = jax.random.normal(key, (seq_len, config.n_vocab))

# %%
def loss_naive(model, X, Y, key):
    Y_chunk = []
    kvs = model._initial_kvs()
    for i in range(0, seq_len, csz):
        Y_pred, kvs = model(X[i : i + csz], kvs, key)
        Y_chunk.append(Y_pred)
    Y_chunk = jnp.concatenate(Y_chunk, axis=0)
    return optax.squared_error(Y_chunk, Y).mean()
loss_fn_naive = eqx.filter_jit(eqx.filter_value_and_grad(loss_naive))
_ = loss_fn_naive(model, X, Y, key) # warmup
timeit.timeit(lambda : loss_fn_naive(model, X, Y, None), number=5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 10
#       8     return optax.squared_error(Y_chunk, Y).mean()
#       9 loss_fn_naive = eqx.filter_jit(eqx.filter_value_and_grad(loss_naive))
# ---> 10 _ = loss_fn_naive(model, X, Y, key) # warmup
#      11 timeit.timeit(lambda : loss_fn_naive(model, X, Y, None), number=5)
#
#     [... skipping hidden 4 frame]
#
# File ~/miniconda3/lib/python3.11/site-packages/jax/_src/pjit.py:248, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     246 @api_boundary
#     247 def cache_miss(*args, **kwargs):
# --> 248   outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked = _python_pjit_helper(
#     249       fun, infer_params_fn, *args, **kwargs)
#     250   executable = _read_most_recent_pjit_call_executable(jaxpr)
#     251   maybe_fastpath_data = _get_fastpath_data(
#     252       executable, out_tree, args_flat, out_flat, attrs_tracked)
#
# File ~/miniconda3/lib/python3.11/site-packages/jax/_src/pjit.py:136, in _python_pjit_helper(fun, infer_params_fn, *args, **kwargs)
#     134 def _python_pjit_helper(fun, infer_params_fn, *args, **kwargs):
#     135   args_flat, _, params, _, out_tree, _, _, _, arg_names, attrs_tracked = \
# --> 136       infer_params_fn(*args, **kwargs)
#     137   for arg in args_flat:
#     138     dispatch.check_arg(arg)
#
# File ~/miniconda3/lib/python3.11/site-packages/jax/_src/api.py:325, in jit.<locals>.infer_params(*args, **kwargs)
#     315 out_layouts = kwargs.pop('_out_layouts', None)
#     316 pjit_info_args = pjit.PjitInfo(
#     317     fun=fun, fun_sourceinfo=fun_sourceinfo, fun_signature=fun_signature,
#     318     in_shardings=in_shardings,
#    (...)
#     323     abstracted_axes=abstracted_axes, in_layouts=in_layouts,
#     324     out_layouts=out_layouts)
# --> 325 return pjit.common_infer_params(pjit_info_args, *args, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/jax/_src/pjit.py:495, in common_infer_params(***failed resolving arguments***)
#     489   in_type = in_avals = tuple(avals)
#     491 canonicalized_in_shardings_flat, in_layouts_flat = _process_in_axis_resources(
#     492     hashable_pytree(in_shardings), hashable_pytree(in_layouts), in_avals,
#     493     in_tree, resource_env, dbg, device_or_backend_set, True if kwargs else False)
# --> 495 jaxpr, consts, out_shardings, out_layouts_flat, attrs_tracked = _pjit_jaxpr(
#     496     flat_fun, hashable_pytree(out_shardings), hashable_pytree(out_layouts),
#     497     in_type, dbg, device_or_backend_set, HashableFunction(out_tree, closure=()),
#     498     HashableFunction(res_paths, closure=()), inline)
#     500 assert len(explicit_args) == len(canonicalized_in_shardings_flat) == len(in_layouts_flat)
#     502 if config.dynamic_shapes.value:
#
# File ~/miniconda3/lib/python3.11/site-packages/jax/_src/pjit.py:1150, in _pjit_jaxpr(fun, out_shardings_thunk, out_layouts_thunk, in_type, debug_info, device_or_backend_set, out_tree, result_paths, inline)
#    1148 def _pjit_jaxpr(fun, out_shardings_thunk, out_layouts_thunk, in_type, debug_info,
#    1149                 device_or_backend_set, out_tree, result_paths, inline):
# -> 1150   jaxpr, final_consts, out_type, attrs_tracked = _create_pjit_jaxpr(
#    1151       fun, in_type, debug_info, result_paths, IgnoreKey(inline))
#    1152   canonicalized_out_shardings_flat, out_layouts_flat = _check_and_canonicalize_out_shardings(
#    1153       out_shardings_thunk, out_layouts_thunk, out_tree, tuple(out_type),
#    1154       jaxpr.jaxpr.debug_info, device_or_backend_set)
#    1155   return jaxpr, final_consts, canonicalized_out_shardings_flat, out_layouts_flat, attrs_tracked
#
# File ~/miniconda3/lib/python3.11/site-packages/jax/_src/linear_util.py:350, in cache.<locals>.memoized_fun(fun, *args)
#     348   fun.populate_stores(stores)
#     349 else:
# --> 350   ans = call(fun, *args)
#     351   if explain and config.explain_cache_misses.value:
#     352     explain(fun.f, cache is new_cache, cache, key, ans)
#
# File ~/miniconda3/lib/python3.11/site-packages/jax/_src/pjit.py:1089, in _create_pjit_jaxpr(***failed resolving arguments***)
#    1087     attrs_tracked = []
#    1088   else:
# -> 1089     jaxpr, global_out_avals, consts, attrs_tracked = pe.trace_to_jaxpr_dynamic(
#    1090         fun, in_type, debug_info=pe_debug)
#    1092 # TODO(dougalm,mattjj): enable debug info with attrs_tracked
#    1093 if not config.dynamic_shapes.value and not attrs_tracked:
#
# File ~/miniconda3/lib/python3.11/site-packages/jax/_src/profiler.py:336, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     333 @wraps(func)
#     334 def wrapper(*args, **kwargs):
#     335   with TraceAnnotation(name, **decorator_kwargs):
# --> 336     return func(*args, **kwargs)
#     337   return wrapper
#
# File ~/miniconda3/lib/python3.11/site-packages/jax/_src/interpreters/partial_eval.py:2314, in trace_to_jaxpr_dynamic(fun, in_avals, debug_info, keep_inputs)
#    2312 with core.new_main(DynamicJaxprTrace, dynamic=True) as main:  # type: ignore
#    2313   main.jaxpr_stack = ()  # type: ignore
# -> 2314   jaxpr, out_avals, consts, attrs_tracked = trace_to_subjaxpr_dynamic(
#    2315     fun, main, in_avals, keep_inputs=keep_inputs, debug_info=debug_info)
#    2316   del main, fun
#    2317 return jaxpr, out_avals, consts, attrs_tracked
#
# File ~/miniconda3/lib/python3.11/site-packages/jax/_src/interpreters/partial_eval.py:2336, in trace_to_subjaxpr_dynamic(fun, main, in_avals, keep_inputs, debug_info)
#    2334 in_tracers = _input_type_to_tracers(trace.new_arg, in_avals)
#    2335 in_tracers_ = [t for t, keep in zip(in_tracers, keep_inputs) if keep]
# -> 2336 ans = fun.call_wrapped(*in_tracers_)
#    2337 out_tracers = map(trace.full_raise, ans)
#    2338 jaxpr, consts, attrs_tracked = frame.to_jaxpr(out_tracers)
#
# File ~/miniconda3/lib/python3.11/site-packages/jax/_src/linear_util.py:192, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     189 gen = gen_static_args = out_store = None
#     191 try:
# --> 192   ans = self.f(*args, **dict(self.params, **kwargs))
#     193 except:
#     194   # Some transformations yield from inside context managers, so we have to
#     195   # interrupt them before reraising the exception. Otherwise they will only
#     196   # get garbage-collected at some later time, running their cleanup tasks
#     197   # only after this exception is handled, which can corrupt the global
#     198   # state.
#     199   while stack:
#
# File ~/miniconda3/lib/python3.11/site-packages/equinox/_jit.py:49, in _filter_jit_cache.<locals>.fun_wrapped(dynamic_donate, dynamic_nodonate, static)
#      47 *args, dummy_arg = (first_arg,) + rest_args
#      48 assert dummy_arg is None
# ---> 49 out = fun(*args, **kwargs)
#      50 dynamic_out, static_out = partition(out, is_array)
#      51 return dynamic_out, Static(static_out)
#
# File ~/miniconda3/lib/python3.11/site-packages/equinox/_ad.py:79, in _ValueAndGradWrapper.__call__(self, *args, **kwargs)
#      77 x, *args = args
#      78 diff_x, nondiff_x = partition(x, is_inexact_array)
# ---> 79 return fun_value_and_grad(diff_x, nondiff_x, *args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/lib/python3.11/site-packages/jax/_src/api.py:745, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     743   _check_input_dtype_grad(holomorphic, allow_int, leaf)
#     744 if not has_aux:
# --> 745   ans, vjp_py = _vjp(f_partial, *dyn_args, reduce_axes=reduce_axes)
#     746 else:
#     747   ans, vjp_py, aux = _vjp(
#     748       f_partial, *dyn_args, has_aux=True, reduce_axes=reduce_axes)
#
# File ~/miniconda3/lib/python3.11/site-packages/jax/_src/api.py:2238, in _vjp(fun, has_aux, reduce_axes, *primals)
#    2236 if not has_aux:
#    2237   flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 2238   out_primal, out_vjp = ad.vjp(
#    2239       flat_fun, primals_flat, reduce_axes=reduce_axes)
#    2240   out_tree = out_tree()
#    2241 else:
#
# File ~/miniconda3/lib/python3.11/site-packages/jax/_src/interpreters/ad.py:143, in vjp(traceable, primals, has_aux, reduce_axes)
#     141 def vjp(traceable, primals, has_aux=False, reduce_axes=()):
#     142   if not has_aux:
# --> 143     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     144   else:
#     145     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# File ~/miniconda3/lib/python3.11/site-packages/jax/_src/interpreters/ad.py:132, in linearize(traceable, *primals, **kwargs)
#     130 _, in_tree = tree_flatten(((primals, primals), {}))
#     131 jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# --> 132 jaxpr, out_pvals, consts = pe.trace_to_jaxpr_nounits(jvpfun_flat, in_pvals)
#     133 out_primals_pvals, out_tangents_pvals = tree_unflatten(out_tree(), out_pvals)
#     134 assert all(out_primal_pval.is_known() for out_primal_pval in out_primals_pvals)
#
# File ~/miniconda3/lib/python3.11/site-packages/jax/_src/profiler.py:336, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     333 @wraps(func)
#     334 def wrapper(*args, **kwargs):
#     335   with TraceAnnotation(name, **decorator_kwargs):
# --> 336     return func(*args, **kwargs)
#     337   return wrapper
#
# File ~/miniconda3/lib/python3.11/site-packages/jax/_src/interpreters/partial_eval.py:774, in trace_to_jaxpr_nounits(fun, pvals, instantiate)
#     772 with core.new_main(JaxprTrace, name_stack=current_name_stack) as main:
#     773   fun = trace_to_subjaxpr_nounits(fun, main, instantiate)
# --> 774   jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     775   assert not env
#     776   del main, fun, env
#
# File ~/miniconda3/lib/python3.11/site-packages/jax/_src/linear_util.py:192, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     189 gen = gen_static_args = out_store = None
#     191 try:
# --> 192   ans = self.f(*args, **dict(self.params, **kwargs))
#     193 except:
#     194   # Some transformations yield from inside context managers, so we have to
#     195   # interrupt them before reraising the exception. Otherwise they will only
#     196   # get garbage-collected at some later time, running their cleanup tasks
#     197   # only after this exception is handled, which can corrupt the global
#     198   # state.
#     199   while stack:
#
# File ~/miniconda3/lib/python3.11/site-packages/equinox/_ad.py:62, in _ValueAndGradWrapper.__call__.<locals>.fun_value_and_grad(_diff_x, _nondiff_x, *_args, **_kwargs)
#      59 @ft.partial(jax.value_and_grad, has_aux=self._has_aux, **self._gradkwargs)
#      60 def fun_value_and_grad(_diff_x, _nondiff_x, *_args, **_kwargs):
#      61     _x = combine(_diff_x, _nondiff_x)
# ---> 62     return self._fun(_x, *_args, **_kwargs)
#
# Cell In[4], line 5, in loss_naive(model, X, Y, key)
#       3 kvs = model._initial_kvs()
#       4 for i in range(0, seq_len, csz):
# ----> 5     Y_pred, kvs = model(X[i : i + csz], kvs, key)
#       6     Y_chunk.append(Y_pred)
#       7 Y_chunk = jnp.concatenate(Y_chunk, axis=0)
#
# File ~/Documents/Main/02_Knowledge_Hut/200 Areas/AI/ideas/src/retnet-expr-decay/__init__.py:171, in ExpressiveRetNet.__call__(self, x, kvs, key)
#     167 new_kvs = []
#     168 for i, (block, key) in enumerate(
#     169     zip(self.blocks, jax.random.split(key, len(self.blocks)))
#     170 ):
# --> 171     x, new_kv = block(x, kvs[i], key)
#     172     new_kvs.append(new_kv)
#     173 new_kvs = jnp.stack(new_kvs)
#
# File ~/Documents/Main/02_Knowledge_Hut/200 Areas/AI/ideas/src/retnet-expr-decay/__init__.py:138, in GatedBlock.__call__(self, x, kvs, key)
#     136 def __call__(self, x, kvs, key):
#     137     key1, key2 = jax.random.split(key, 2)
# --> 138     y, kvs = self.retention(jax.vmap(self.ln1)(x), kvs)
#     139     y = jax.nn.swish(jax.vmap(self.g)(y))  # Gate inspired by RetNet
#     140     x += self.drop1(y, key=key1)
#
# File ~/Documents/Main/02_Knowledge_Hut/200 Areas/AI/ideas/src/retnet-expr-decay/__init__.py:80, in EDMultiheadRetention.__call__(self, x, kvs)
#      77 out = jax.nn.gelu(attn @ v + q @ (kvs * self.alpha[:, :, None] ** sqlen))
#      78 out = out.transpose(1, 0, 2).reshape(sqlen, self.config.d_model)
# ---> 80 new_kvs = kvs * (self.alpha[:, :, None] ** (sqlen))
#      81 new_kvs += jnp.einsum("hdi,hdj->hij", k, v)
#      83 return out, new_kvs
#
# File ~/miniconda3/lib/python3.11/site-packages/jax/_src/numpy/array_methods.py:736, in _forward_operator_to_aval.<locals>.op(self, *args)
#     735 def op(self, *args):
# --> 736   return getattr(self.aval, f"_{name}")(self, *args)
#
# File ~/miniconda3/lib/python3.11/site-packages/jax/_src/numpy/array_methods.py:264, in _defer_to_unrecognized_arg.<locals>.deferring_binary_op(self, other)
#     262 args = (other, self) if swap else (self, other)
#     263 if isinstance(other, _accepted_binop_types):
# --> 264   return binary_op(*args)
#     265 # Note: don't use isinstance here, because we don't want to raise for
#     266 # subclasses, e.g. NamedTuple objects that may override operators.
#     267 if type(other) in _rejected_binop_types:
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/lib/python3.11/site-packages/jax/_src/pjit.py:248, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     246 @api_boundary
#     247 def cache_miss(*args, **kwargs):
# --> 248   outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked = _python_pjit_helper(
#     249       fun, infer_params_fn, *args, **kwargs)
#     250   executable = _read_most_recent_pjit_call_executable(jaxpr)
#     251   maybe_fastpath_data = _get_fastpath_data(
#     252       executable, out_tree, args_flat, out_flat, attrs_tracked)
#
# File ~/miniconda3/lib/python3.11/site-packages/jax/_src/pjit.py:136, in _python_pjit_helper(fun, infer_params_fn, *args, **kwargs)
#     134 def _python_pjit_helper(fun, infer_params_fn, *args, **kwargs):
#     135   args_flat, _, params, _, out_tree, _, _, _, arg_names, attrs_tracked = \
# --> 136       infer_params_fn(*args, **kwargs)
#     137   for arg in args_flat:
#     138     dispatch.check_arg(arg)
#
# File ~/miniconda3/lib/python3.11/site-packages/jax/_src/api.py:325, in jit.<locals>.infer_params(*args, **kwargs)
#     315 out_layouts = kwargs.pop('_out_layouts', None)
#     316 pjit_info_args = pjit.PjitInfo(
#     317     fun=fun, fun_sourceinfo=fun_sourceinfo, fun_signature=fun_signature,
#     318     in_shardings=in_shardings,
#    (...)
#     323     abstracted_axes=abstracted_axes, in_layouts=in_layouts,
#     324     out_layouts=out_layouts)
# --> 325 return pjit.common_infer_params(pjit_info_args, *args, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/jax/_src/pjit.py:491, in common_infer_params(***failed resolving arguments***)
#     485       raise OverflowError(
#     486         "An overflow was encountered while parsing an argument to a jitted "
#     487         f"computation, whose {arg_path}."
#     488       ) from e
#     489   in_type = in_avals = tuple(avals)
# --> 491 canonicalized_in_shardings_flat, in_layouts_flat = _process_in_axis_resources(
#     492     hashable_pytree(in_shardings), hashable_pytree(in_layouts), in_avals,
#     493     in_tree, resource_env, dbg, device_or_backend_set, True if kwargs else False)
#     495 jaxpr, consts, out_shardings, out_layouts_flat, attrs_tracked = _pjit_jaxpr(
#     496     flat_fun, hashable_pytree(out_shardings), hashable_pytree(out_layouts),
#     497     in_type, dbg, device_or_backend_set, HashableFunction(out_tree, closure=()),
#     498     HashableFunction(res_paths, closure=()), inline)
#     500 assert len(explicit_args) == len(canonicalized_in_shardings_flat) == len(in_layouts_flat)
#
# File ~/miniconda3/lib/python3.11/site-packages/jax/_src/util.py:452, in HashableFunction.__hash__(self)
#     451 def __hash__(self):
# --> 452   return hash((self.f.__code__, self.closure))
#
# KeyboardInterrupt:

# %%
def loss_scan(model, X, Y, key):
    def step(kvs, x):
        y, kvs = model(x, kvs, key)
        return kvs, y
        
    kvs = model._initial_kvs()
    kvs, Y_chunk = jax.lax.scan(step, kvs, X.reshape(-1, csz))
    Y_chunk = jnp.concatenate(Y_chunk, axis=0)
    return optax.squared_error(Y_chunk, Y).mean()
loss_fn_scan = eqx.filter_jit(eqx.filter_value_and_grad(loss_scan))
_ = loss_fn_scan(model, X, Y, key) # warmup
timeit.timeit(lambda : loss_fn_scan(model, X, Y, key), number=5)
# Out:
# 9.750562791945413
